# %%
import sys

print(sys.prefix != sys.base_prefix)

import os
print('VIRTUAL_ENV' in os.environ)
# true mean you are in the virutal environment
# Out:
# True
# True

# %%
# %pip install PyDirectInput
# %pip install opencv-python
# %pip install mediapipe
# %pip install numpy
# Out:
# Collecting PyDirectInput
#   Using cached PyDirectInput-1.0.4-py3-none-any.whl.metadata (3.9 kB)
# Using cached PyDirectInput-1.0.4-py3-none-any.whl (8.9 kB)
# Installing collected packages: PyDirectInput
# Successfully installed PyDirectInput-1.0.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting opencv-python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy>=2 (from opencv-python)
#   Downloading numpy-2.5.3-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Downloading numpy-2.5.3-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 3.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/12.6 MB 3.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/12.6 MB 3.2 MB/s eta 0:00:04
#    ------- -------------------------------- 2.4/12.6 MB 3.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/12.6 MB 3.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.7/12.6 MB 3.1 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.6 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.6 MB 3.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.6 MB 3.0 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.6 MB 3.1 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.6 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.6 MB 3.1 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.6 MB 3.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.6 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.6 MB 3.0 MB/s eta 0:00:02
#    ------------------------------- -------- 10.0/12.6 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 3.0 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-2.5.3 opencv-python-5.0.0.93
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting mediapipe
#   Using cached mediapipe-1.0.1-py3-none-win_amd64.whl.metadata (10 kB)
# Collecting absl-py~=2.3 (from mediapipe)
#   Using cached absl_py-2.5.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting certifi (from mediapipe)
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy in c:\users\calvin.nguyen\onedrive - skechers usa\documents\side projects\subway-surfers-cv\.venv\lib\site-packages (from mediapipe) (2.5.3)
# Collecting sounddevice~=0.5 (from mediapipe)
#   Using cached sounddevice-0.5.6-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting flatbuffers~=25.9 (from mediapipe)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting cffi (from sounddevice~=0.5->mediapipe)
#   Downloading cffi-2.1.1-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib->mediapipe)
#   Downloading fonttools-4.65.0-cp312-cp312-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\calvin.nguyen\onedrive - skechers usa\documents\side projects\subway-surfers-cv\.venv\lib\site-packages (from matplotlib->mediapipe) (26.3)
# Collecting pillow>=9 (from matplotlib->mediapipe)
#   Using cached pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib->mediapipe)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\calvin.nguyen\onedrive - skechers usa\documents\side projects\subway-surfers-cv\.venv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\calvin.nguyen\onedrive - skechers usa\documents\side projects\subway-surfers-cv\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Collecting pycparser (from cffi->sounddevice~=0.5->mediapipe)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached mediapipe-1.0.1-py3-none-win_amd64.whl (20.1 MB)
# Using cached absl_py-2.5.0-py3-none-any.whl (137 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached sounddevice-0.5.6-py3-none-win_amd64.whl (1.0 MB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# Downloading matplotlib-3.11.2-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.3 MB 3.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.3 MB 3.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/9.3 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.3 MB 3.1 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.3 MB 3.1 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.3 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.3 MB 3.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.3 MB 3.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.8/9.3 MB 3.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.0 MB/s eta 0:00:00
# Using cached opencv_contrib_python-5.0.0.93-cp37-abi3-win_amd64.whl (53.8 MB)
# Downloading contourpy-1.4.0-cp312-cp312-win_amd64.whl (234 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 2.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.5 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Using cached pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading cffi-2.1.1-cp312-cp312-win_amd64.whl (185 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: flatbuffers, pyparsing, pycparser, pillow, opencv-contrib-python, kiwisolver, fonttools, cycler, contourpy, certifi, absl-py, matplotlib, cffi, sounddevice, mediapipe
# Successfully installed absl-py-2.5.0 certifi-2026.7.22 cffi-2.1.1 contourpy-1.4.0 cycler-0.12.1 flatbuffers-25.12.19 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.11.2 mediapipe-1.0.1 opencv-contrib-python-5.0.0.93 pillow-12.3.0 pycparser-3.0 pyparsing-3.3.2 sounddevice-0.5.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\calvin.nguyen\onedrive - skechers usa\documents\side projects\subway-surfers-cv\.venv\lib\site-packages (2.5.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mediapipe as mp
import numpy as np 
import pydirectinput
import cv2
import time

# %%
cap = cv2.VideoCapture(0)
cap
# Out:
# < cv2.VideoCapture 0000022145868C50>

# %%
cap.isOpened()
# Out:
# True
